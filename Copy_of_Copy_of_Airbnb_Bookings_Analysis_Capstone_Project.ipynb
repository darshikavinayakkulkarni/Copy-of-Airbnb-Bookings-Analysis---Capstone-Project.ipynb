# %% [markdown]
# <a href="https://colab.research.google.com/github/darshikavinayakkulkarni/Copy-of-Airbnb-Bookings-Analysis---Capstone-Project.ipynb/blob/main/Copy_of_Copy_of_Airbnb_Bookings_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# ## <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# ## <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Group member no.1: Shubham:

# %%
url='https://drive.google.com/file/d/1ioU5r9KEYSfwgfUi22SclVkx4l1a_8ou/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
air_bnb = pd.read_csv(url)

# %%
air_bnb
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
air_bnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
air_bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
air_bnb.shape
# Out:
# (48895, 16)

# %%
air_bnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
air_bnb.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
air_bnb['name'].fillna('No name', inplace= True)
air_bnb['host_name'].fillna('No name', inplace= True)

# %%
air_bnb.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Removed columns with maximum number of null values
air_bnb.drop(['reviews_per_month'], axis=1, inplace= True)
air_bnb.drop(['last_review'], axis=1, inplace= True)

# %%
## Q1 Check availability of room type according to average price.
room_price= air_bnb.groupby(['room_type','availability_365'])['price'].mean().reset_index()
room_price= room_price.sort_values('price', ascending= False).head(5)
room_price
# Out:
#            room_type  availability_365       price
# 892      Shared room               269  800.000000
# 877      Shared room               220  800.000000
# 851      Shared room               173  645.000000
# 150  Entire home/apt               150  547.263158
# 180  Entire home/apt               180  501.203125

# %%
room_price.plot.bar(x='room_type', rot=0, stacked= True, xlabel= 'Type of rooms', title= 'Average Price vs Availability', figsize= (12,8), fontsize= 'large');

# %%
## Q2 Which property is more preferred by the guests?
preference= air_bnb.groupby(['name','neighbourhood_group','neighbourhood'])['number_of_reviews'].max().reset_index()
preference= preference.sort_values('number_of_reviews', ascending= False).head(15)
preference
# Out:
#                                                     name neighbourhood_group  \
# 36831                            Room near JFK Queen Bed              Queens
# 21016                         Great Bedroom in Manhattan           Manhattan
# 5735                      Beautiful Bedroom in Manhattan           Manhattan
# 33033                       Private Bedroom in Manhattan           Manhattan
# 36473                            Room Near JFK Twin Beds              Queens
# 40882                  Steps away from Laguardia airport              Queens
# 27925           Manhattan Lux Loft.Like.Love.Lots.Look !           Manhattan
# 15344  Cozy Room Family Home LGA Airport NO CLEANING FEE              Queens
# 34350                 Private brownstone studio Brooklyn            Brooklyn
# 23991                    LG Private Room/Family Friendly            Brooklyn
# 29526                   My Little Guest Room in Flushing              Queens
# ...

# %%
sns.boxplot(x='number_of_reviews', y='neighbourhood', data=preference);

# %%
## Q3 In which areas the most of the business is done?
list1= air_bnb.loc[0:,['number_of_reviews','neighbourhood_group']]
dict_1= list1.set_index('number_of_reviews').T.to_dict('list')
final_dict=[]
for i,j in dict_1.items():
  if i>0:
    final_dict.append(j)

unique_neigh=()
for item in final_dict:
    unique_neigh = list(set(unique_neigh) | set(item))
unique_neigh
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ['Queens', 'Staten Island', 'Manhattan', 'Brooklyn', 'Bronx']

# %%
# Observation done: ['Queens', 'Staten Island', 'Manhattan', 'Brooklyn', 'Bronx'] has most reviews and hence there is need of business improvement in other remaining areas.

# %%
## Q4. What are the type of rooms and What are their average prices?
room_types_uni = air_bnb['room_type'].unique()
for i in room_types_uni:
    avg_price = round(np.mean(air_bnb['price'][air_bnb['room_type']==i],0))
    print(f'The median price of a {i} is {avg_price}')
# Out:
# The median price of a Private room is 90
# The median price of a Entire home/apt is 212
# The median price of a Shared room is 70

# %%
## So mainly there are 3 types of rooms and home/apt has the highest average price.

# %%
##Asked Q1. What can we learn about different hosts and areas?
hosts_areas= air_bnb.groupby(['host_name', 'neighbourhood_group','neighbourhood'])['calculated_host_listings_count'].max().reset_index()
hosts_areas= hosts_areas.sort_values('calculated_host_listings_count', ascending= False).head(15)
hosts_areas
# Out:
#           host_name neighbourhood_group       neighbourhood  \
# 25267  Sonder (NYC)           Manhattan    Theater District
# 25264  Sonder (NYC)           Manhattan      Hell's Kitchen
# 25262  Sonder (NYC)           Manhattan             Chelsea
# 25263  Sonder (NYC)           Manhattan  Financial District
# 25268  Sonder (NYC)           Manhattan     Upper East Side
# 25265  Sonder (NYC)           Manhattan             Midtown
# 25266  Sonder (NYC)           Manhattan         Murray Hill
# 3543     Blueground           Manhattan              Nolita
# 3540     Blueground           Manhattan             Midtown
# 3532     Blueground           Manhattan             Chelsea
# 3539     Blueground           Manhattan     Lower East Side
# 3538     Blueground           Manhattan            Kips Bay
# 3537     Blueground           Manhattan      Hell's Kitchen
# 3536     Blueground           Manhattan            Gramercy
# 3544     Blueground           Manhattan                SoHo
#
# ...

# %%
## Hosts such as Sonder (NYC), Blueground from Manhattan are busy.

# %%
##Asked Q2. What can we learn from predictions? (ex: locations, prices, reviews, etc)
predictions= air_bnb.groupby(['latitude','longitude','neighbourhood_group','neighbourhood','price'])['number_of_reviews'].max().reset_index()
predictions.sort_values('price', ascending= False).head(5)
# Out:
#        latitude  longitude neighbourhood_group    neighbourhood  price  \
# 38522  40.76810  -73.91651              Queens          Astoria  10000
# 27860  40.73260  -73.95739            Brooklyn       Greenpoint  10000
# 39324  40.77213  -73.98665           Manhattan  Upper West Side  10000
# 23108  40.71980  -73.98566           Manhattan  Lower East Side   9999
# 20437  40.71355  -73.98507           Manhattan  Lower East Side   9999
#
#        number_of_reviews
# 38522                  2
# 27860                  5
# 39324                  0
# 23108                  0
# 20437                  6

# %%
predictions.sort_values('number_of_reviews', ascending= False).head(5)
# Out:
#        latitude  longitude neighbourhood_group neighbourhood  price  \
# 4774   40.66730  -73.76831              Queens       Jamaica     47
# 45833  40.82085  -73.94025           Manhattan        Harlem     49
# 45872  40.82124  -73.93838           Manhattan        Harlem     49
# 46050  40.82264  -73.94041           Manhattan        Harlem     49
# 5142   40.66939  -73.76975              Queens       Jamaica     47
#
#        number_of_reviews
# 4774                 629
# 45833                607
# 45872                597
# 46050                594
# 5142                 576

# %%
##Asked Q3. Which hosts are the busiest and why?
busy_hosts= air_bnb.groupby('host_name')['minimum_nights'].max().reset_index()
busy_hosts= busy_hosts.sort_values('minimum_nights', ascending= False).head(10)
busy_hosts
# Out:
#       host_name  minimum_nights
# 3590  Genevieve            1250
# 8281      Peter            1000
# 7018        Meg             999
# 3751   Glenn H.             999
# 675       Angie             999
# 4989       John             500
# 5923      Laura             500
# 472      Amanda             500
# 395       Aliya             500
# 9579    Shining             480

# %%
busy_hosts.plot(x='host_name',y='minimum_nights', figsize=(12,8), xlabel='Host', title= 'Most Busy Hosts');

# %%
## It is clear that the most busy hosts are Genevieve, Peter and Meg as the they have the highest number of night stay counts.

# %%
##Asked Q4. Is there any noticeable difference of traffic among different areas and what could be the reason for it?
traffic= air_bnb.groupby(['neighbourhood_group','neighbourhood','room_type','price'])['minimum_nights'].max().reset_index()
traffic.sort_values('minimum_nights', ascending= False).head(10)
# Out:
#       neighbourhood_group      neighbourhood        room_type  price  \
# 7076            Manhattan  Greenwich Village  Entire home/apt    180
# 5468            Manhattan  Battery Park City  Entire home/apt    400
# 7229            Manhattan             Harlem  Entire home/apt     99
# 7190            Manhattan  Greenwich Village      Shared room    110
# 5243             Brooklyn       Williamsburg     Private room     79
# 12500              Queens   Long Island City  Entire home/apt    134
# 2553             Brooklyn      Crown Heights     Private room     50
# 5017             Brooklyn       Williamsburg  Entire home/apt    140
# 3919             Brooklyn         Kensington     Private room     45
# 7206            Manhattan             Harlem  Entire home/apt     75
#
#        minimum_nights
# 7076             1250
# 5468             1000
# 7229              999
# 7190              999
# 5243              999
# 12500             500
# 2553              500
# ...

# %%
## From the above data we can say that the traffic is quite high for Entire home/apt in Manhattan due to average price range.

# %%
## Group member no.2: Mayur:

# %%
url='https://drive.google.com/file/d/1ioU5r9KEYSfwgfUi22SclVkx4l1a_8ou/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)

# %%
new_df = df[['id','name','host_id','host_name','neighbourhood_group','neighbourhood','room_type','price','minimum_nights','number_of_reviews',
             'calculated_host_listings_count', 'availability_365']]
new_df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
## 1 WHICH ARE MOST CHEAPER HOSTS?
cheaper_hosts = new_df.groupby(['host_name','price','room_type','neighbourhood_group'])['minimum_nights'].count().reset_index()
cheaper_hosts = cheaper_hosts.sort_values(by='price',ascending=True).head(10)
cheaper_hosts
# Out:
#           host_name  price        room_type neighbourhood_group  \
# 23180        Lauren      0     Private room            Brooklyn
# 3117         Anisha      0     Private room               Bronx
# 433         Adeyemi      0     Private room            Brooklyn
# 35515        Sergii      0      Shared room            Brooklyn
# 22308      Kimberly      0     Private room            Brooklyn
# 26478  Martial Loft      0     Private room            Brooklyn
# 4490        Aymeric      0  Entire home/apt            Brooklyn
# 32216        Qiuchi      0  Entire home/apt           Manhattan
# 34438         Salim     10     Private room           Manhattan
# 29002        Morgan     10      Shared room           Manhattan
#
#        minimum_nights
# 23180               1
# 3117                1
# 433                 3
# 35515               2
# 22308               1
# 26478               1
# 4490                1
# 32216               1
# 34438               1
# 29002               1

# %%
# A function for price_correction
def price_correction(x):
    if x==0:
        return 100
    else:
        return x

# %%
df[df['price']==0]
#Rows which have 'price'=0
# Out:
#              id                                               name    host_id  \
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 25433  20333471      ★Hostel Style Room | Ideal Traveling Buddies★  131697576
# 25634  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 25753  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 25794  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 25795  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 25796  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 26259  20933849                              the best you can find   13709292
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
#
# ...

# %%
# Using the price_correction function to change the 'price'
df['price']=df['price'].apply(price_correction)

# %%
# 'price' has no value equal to zero
df[df['price']==0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
#Changing values of 'minimum_nights' to 365 which are greater than 365
df['minimum_nights']=df['minimum_nights'].apply(lambda x: 365 if x>365 else x)

# %%
#What are maximum host listings
max_hostid=df['host_id'].value_counts().head(10)
max_hostid
#Considering 10 highest host_id listings.The maximum host_id listing is 327.
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
# 12243051      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# Name: host_id, dtype: int64

# %%
#creating a dataframe with max_hostid data
df_hostid=pd.DataFrame(data=max_hostid)
df_hostid.reset_index(inplace=True)
df_hostid.rename(columns={'index':'Host_ID', 'host_id':'Listings_Count'}, inplace=True)
df_hostid
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2dbbbe67f3a0> in <module>
#       1 #creating a dataframe with max_hostid data
# ----> 2 df_hostid=pd.DataFrame(data=max_hostid)
#       3 df_hostid.reset_index(inplace=True)
#       4 df_hostid.rename(columns={'index':'Host_ID', 'host_id':'Listings_Count'}, inplace=True)
#       5 df_hostid
#
# NameError: name 'max_hostid' is not defined

# %%
#setting the runtime configuration and parameters for all visualizatins
import seaborn as sns
sns.set(rc={'figure.figsize':(10,6)})
sns.set_style('white')

# %%
fig_1=sns.barplot(x='Host_ID',y='Listings_Count',data=df_hostid)
fig_1.set_title('Hosts with the most listings')
fig_1.set_ylabel('Count of listings')
fig_1.set_xlabel('Host IDs')
fig_1.set_xticklabels(fig_1.get_xticklabels(), rotation=45)
# fig_1 states that the number of listing in top 10 is numerous
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e5db32aa2b0d> in <module>
# ----> 1 fig_1=sns.barplot(x='Host_ID',y='Listings_Count',data=df_hostid)
#       2 fig_1.set_title('Hosts with the most listings')
#       3 fig_1.set_ylabel('Count of listings')
#       4 fig_1.set_xlabel('Host IDs')
#       5 fig_1.set_xticklabels(fig_1.get_xticklabels(), rotation=45)
#
# NameError: name 'df_hostid' is not defined

# %%
#What are various room types available
room_type_data=df['room_type'].value_counts()
room_type_data
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
df_room_type=pd.DataFrame(data=room_type_data)
df_room_type.reset_index(inplace=True)
df_room_type.rename(columns={'index':'Room_Type','room_type':'Count'},inplace=True)
df_room_type
# Out:
#          Room_Type  Count
# 0  Entire home/apt  25409
# 1     Private room  22326
# 2      Shared room   1160

# %%
fig_4=sns.countplot(x=df['room_type'],hue=df['neighbourhood_group'])
fig_4

# %%
all_neighbourhood_group=df['neighbourhood_group'].value_counts()
all_neighbourhood_group
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
df_neighbourhood_group=pd.DataFrame(data=all_neighbourhood_group)
df_neighbourhood_group.reset_index(inplace=True)
df_neighbourhood_group.rename(columns={'index':'Neighbourhood_Group','neighbourhood_group':'Counts'},
                              inplace=True)
df_neighbourhood_group
# Out:
#   Neighbourhood_Group  Counts
# 0           Manhattan   21661
# 1            Brooklyn   20104
# 2              Queens    5666
# 3               Bronx    1091
# 4       Staten Island     373

# %%
fig_2=sns.barplot(x=df_neighbourhood_group['Neighbourhood_Group'],y=df_neighbourhood_group['Counts'])
fig_2.set_title('Listings in Each Neighbourhood')
fig_2.set_xlabel('Neighbourhood_Group')
fig_2.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
#Observation
#1)Most Listings offer Entire home followed by Private Room and Shared Room

#2)Brooklyn offers nearly the same number of private rooms and entire home whereas Manhattan offers highest number of entire homes followed byprivate rooms.

#3)Listing of shared room is very little and staten islands and bronx offer very few shared rooms

# %%
#What can we learn about different hosts and areas?
host_areas = df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].count().reset_index()
host_areas.sort_values(by='calculated_host_listings_count',ascending=False).head(5)
# Out:
#           host_name neighbourhood_group  calculated_host_listings_count
# 13217  Sonder (NYC)           Manhattan                             327
# 1834     Blueground           Manhattan                             230
# 9742        Michael           Manhattan                             212
# 3250          David           Manhattan                             202
# 9741        Michael            Brooklyn                             159

# %%
AS WE CAN SEE MOST NUMBER OF LISTINGS ARE FROM *MANHATTAN * Created Sonder(NYC),BLUEGROUND,MICHAEL,DAVID.

# %%
#Traffic among different areas?
traffic_areas = new_df.groupby(['neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
traffic_areas = traffic_areas.sort_values(by='minimum_nights',ascending=False)
traffic_areas
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt           13199
# 4             Brooklyn     Private room           10132
# 3             Brooklyn  Entire home/apt            9559
# 7            Manhattan     Private room            7982
# 10              Queens     Private room            3372
# 9               Queens  Entire home/apt            2096
# 1                Bronx     Private room             652
# 8            Manhattan      Shared room             480
# 5             Brooklyn      Shared room             413
# 0                Bronx  Entire home/apt             379
# 11              Queens      Shared room             198
# 13       Staten Island     Private room             188
# 12       Staten Island  Entire home/apt             176
# 2                Bronx      Shared room              60
# 14       Staten Island      Shared room               9

# %%
## Group member no.3: Darshika:

# %%
url='https://drive.google.com/file/d/1ioU5r9KEYSfwgfUi22SclVkx4l1a_8ou/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df1 = pd.read_csv(url)

# %%
#1. List the room available for 365 days.
df1.availability_365.value_counts()
# Out:
# 0      17533
# 365     1295
# 364      491
# 1        408
# 89       361
#        ...
# 195       26
# 183       24
# 196       24
# 181       23
# 202       20
# Name: availability_365, Length: 366, dtype: int64

# %%
We listed available days of the rooms so our conclusion is there are 17533 rooms available for 0 days.

# %%
#2 which host having maximum reviews?
max_reviews=df1.number_of_reviews.max()
max_host = df1[df1['number_of_reviews']==max_reviews]['host_name']
print(max_host,max_reviews)
# Out:
# 11759    Dona
# Name: host_name, dtype: object 629

# %%
The Dona have maximum number of reviews around 629

# %%
#3. Which location have maximum hotels?
location_per_count = df1['neighbourhood_group'].value_counts().plot(kind='bar',
                                    figsize=(20,10),
                                    title="Show the count of hotels for specific group")

# %%
#4.which room type have maximum preference?
room_preference = df1.room_type.value_counts().plot(
    kind='pie', y='preferance_of_each_class', autopct='%1.0f%%')

# %%
There are maximum people giving preferences to entire home/apt and its around 52% but similary to private room also its around 46%. There are very less preference to the shared room and its around 2%.
